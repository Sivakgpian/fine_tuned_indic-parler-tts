# %%
# !git clone https://github.com/huggingface/dataspeech.git
# Out:
# Cloning into 'dataspeech'...
# remote: Enumerating objects: 650, done.
# remote: Counting objects: 100% (221/221), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 650 (delta 138), reused 131 (delta 131), pack-reused 429 (from 1)
# Receiving objects: 100% (650/650), 158.78 KiB | 833.00 KiB/s, done.
# Resolving deltas: 100% (395/395), done.

# %%
# !cd dataspeech

# %%
# !pip install --quiet -r ./dataspeech/requirements.txt
# Out:
#      - 49.0 MB 37.3 MB/s 0:00:04
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 17.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.1/87.1 kB 6.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 11.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !git config --global credential.helper store
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) y
# Token is valid (permission: write).
# The token `Indic-parler-tts` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved in your configured git credential helpers (store).
# ...

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd dataspeech
# Out:
# /content/dataspeech

# %%
pip install numpy==1.26.3
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 61.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 2.0.5 requires pydantic>=2.9.2, but you have pydantic 2.8.2 which is incompatible.
# ...

# %%
# default="validation", line no 33

# %%
# !python main.py "sivakgp/hindi-books-audio" \
  --configuration "default" \
  --text_column_name "transcription" \
  --audio_column_name "audio" \
  --cpu_num_workers 2 \
  --num_workers_per_gpu_for_pitch 2 \
  --rename_column \
  --repo_id "hindi-books-audio-validation-tags"
# Out:
# 2025-03-21 05:21:24.746288: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742534485.066417    1241 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742534485.143442    1241 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-21 05:21:25.748839: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python ./scripts/metadata_to_text.py \
    "sivakgp/hindi-books-audio-validation-tags" \
    --repo_id "sivakgp/hindi-books-audio-train-validation-tags" \
    --configuration "default" \
    --cpu_num_workers 2 \
    --path_to_bin_edges "./examples/tags_to_annotations/v01_bin_edges.json" \
    --avoid_pitch_computation
# Out:
# README.md: 100% 628/628 [00:00<00:00, 4.68MB/s]
# validation-00000-of-00001.parquet: 100% 17.0k/17.0k [00:00<00:00, 62.1MB/s]
# train-00000-of-00001.parquet: 100% 99.0k/99.0k [00:00<00:00, 4.88MB/s]
# Setting num_proc from 2 back to 1 for the train split to disable multiprocessing as it only contains one shard.
# Generating train split: 100% 702/702 [00:00<00:00, 112747.52 examples/s]
# Setting num_proc from 2 back to 1 for the validation split to disable multiprocessing as it only contains one shard.
# Generating validation split: 100% 94/94 [00:00<00:00, 34927.76 examples/s]
# Already computed bin edges have been passed for speaking_rate. Will use: [3.508771929824561, 6.187242299296628, 8.865712668768696, 11.544183038240764, 14.22265340771283, 16.901123777184896, 19.579594146656966, 22.258064516129032].
# Map (num_proc=2): 100% 702/702 [00:03<00:00, 202.53 examples/s]
# Map (num_proc=2): 100% 94/94 [00:04<00:00, 20.49 examples/s]
# ...

# %%
# !python ./scripts/run_prompt_creation.py \
  --speaker_name "Siva" \
  --is_single_speaker \
  --dataset_name "sivakgp/hindi-books-audio-train-validation-tags" \
  --output_dir "./tmp_jenny" \
  --dataset_config_name "default" \
  --model_name_or_path "google/gemma-2b-it" \
  --per_device_eval_batch_size 12 \
  --attn_implementation "sdpa" \
  --dataloader_num_workers 2 \
  --push_to_hub \
  --hub_dataset_id "hindi-books-audio-train-validation-description" \
  --preprocessing_num_workers 2
# Out:
# 03/21/2025 05:36:24 - INFO - __main__ - *** Load annotated dataset ***
# README.md: 100% 747/747 [00:00<00:00, 5.29MB/s]
# validation-00000-of-00001.parquet: 100% 17.7k/17.7k [00:00<00:00, 51.7MB/s]
# train-00000-of-00001.parquet: 100% 95.5k/95.5k [00:00<00:00, 3.77MB/s]
# Setting num_proc from 2 back to 1 for the train split to disable multiprocessing as it only contains one shard.
# 03/21/2025 05:36:29 - WARNING - datasets.builder - Setting num_proc from 2 back to 1 for the train split to disable multiprocessing as it only contains one shard.
# Generating train split: 100% 702/702 [00:00<00:00, 94626.60 examples/s]
# Setting num_proc from 2 back to 1 for the validation split to disable multiprocessing as it only contains one shard.
# 03/21/2025 05:36:29 - WARNING - datasets.builder - Setting num_proc from 2 back to 1 for the validation split to disable multiprocessing as it only contains one shard.
# Generating validation split: 100% 94/94 [00:00<00:00, 32751.67 examples/s]
# ...
